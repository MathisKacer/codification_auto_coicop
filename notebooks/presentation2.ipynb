# %%
import sys
sys.path.append("/home/onyxia/work/codification_auto_coicop")
from data.load_data import charger_base

df = charger_base()

print(df.columns)

print(df)
# Out:
# Index(['id', 'raw_product', 'l_pr_product', 'shop', 'shop_type_name', 'budget',
#        'code', 'lcs_code', 'lcs_distance', 'lcs_substring', 'lcs_prop',
#        'rag_code', 'rag_confidence', 'codable', 'ttc_code_1', 'ttc_conf_1',
#        'ttc_code_2', 'ttc_conf_2', 'ttc_code_3', 'ttc_conf_3', 'ragann_code',
#        'ragann_confidence', 'ragann_codable', 'llm_model', 'llm_timestamp',
#        'llm_code', 'llm_libelle', 'llm_explication', 'llm_confiance',
#        'llm_prompt_tokens', 'llm_completion_tokens', 'llm_latency_s',
#        'llm_error', 's_pr_product', 'source', 'annee', 'coicop', 'n_obs'],
#       dtype='object')
#                                         id  \
# 0     002105d8-a41f-4106-95e9-13900e97bf52
# 1     002e9426-0d41-4a4e-81fd-9b9fb50f5a72
# 2     00324394-4514-4451-9123-9ef2ca5fc401
# 3     00003629-f540-48c6-ab5a-3fb23c9aa2d4
# 4     001d7254-2f5e-4c2e-825d-3d99da8d4734
# ...                                    ...
# 5838  f3bc99ef-6294-4c36-8163-ed5b848dce34
# ...
