# %%
import sys
sys.path.append("/home/onyxia/work/codification_auto_coicop")
# TODO casse avant reorg : charger_base() n'existe plus dans data/load_data.py
# (seule charger_donnees(chemin_s3, ...) existe) -- notebook archive non rejoue.
from data.load_data import charger_base

df = charger_base()

print(df.columns)

print(df)
